# %%
pip install requests beautifulsoup4 pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd

dane = [
    {
        "Soczewka": "Clareon",
        "Wiek": 67.2,
        "Płeć % Kobiet": 60,
        "Czas trwania": "2017-07 → 2019-02",
        "UDVA 20/40 (%)": 98,
        "Liczba pacjentów": 140
    },
    {
        "Soczewka": "PanOptix",
        "Wiek": 68.5,
        "Płeć % Kobiet": 55,
        "Czas trwania": "2020-03 → 2022-05",
        "UDVA 20/20 (%)": 92,
        "UNVA 20/32 (%)": 88,
        "Liczba pacjentów": 200
    },
    {
        "Soczewka": "Vivity",
        "Wiek": 69.1,
        "Płeć % Kobiet": 58,
        "Czas trwania": "2020-06 → 2022-09",
        "UDVA 20/40 (%)": 96,
        "UIVA 20/40 (%)": 90,
        "Liczba pacjentów": 180
    }
]

df = pd.DataFrame(dane)
display(df)
# Out:
#    Soczewka  Wiek  Płeć % Kobiet       Czas trwania  UDVA 20/40 (%)  \
# 0   Clareon  67.2             60  2017-07 → 2019-02            98.0
# 1  PanOptix  68.5             55  2020-03 → 2022-05             NaN
# 2    Vivity  69.1             58  2020-06 → 2022-09            96.0
#
#    Liczba pacjentów  UDVA 20/20 (%)  UNVA 20/32 (%)  UIVA 20/40 (%)
# 0               140             NaN             NaN             NaN
# 1               200            92.0            88.0             NaN
# 2               180             NaN             NaN            90.0

# %%
# Dane
dane = {
    "Soczewka": ["Clareon", "PanOptix", "Vivity"],
    "UDVA ≥ 20/40": [98, None, 96],
    "UDVA ≥ 20/20": [None, 92, None],
    "UNVA ≥ 20/32": [None, 88, None],
    "UIVA ≥ 20/40": [None, None, 90]
}

df = pd.DataFrame(dane).set_index("Soczewka")

# Wykres
df.plot(kind="bar", figsize=(10, 6))
plt.title("Skuteczność widzenia bez okularów")
plt.ylabel("% pacjentów")
plt.xticks(rotation=0)
plt.grid(True, axis='y')
plt.ylim(0, 105)
plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %%
df.plot(x="Soczewka", y="Liczba pacjentów", kind="bar", color="gray", title="Liczba pacjentów w badaniach")
# Out:
# <Axes: title={'center': 'Liczba pacjentów w badaniach'}, xlabel='Soczewka'>
